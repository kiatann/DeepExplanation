# %%
import datasets
import os
import pickle
import random
import re
import scipy
import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from datasets import Dataset

from sklearn.pipeline import make_pipeline

from tqdm.auto import tqdm, trange

from transformers import AutoTokenizer, BigBirdForSequenceClassification, pipeline, \
                            TrainingArguments, Trainer

from torch.utils.data import DataLoader

# %% [markdown]
# #### Getting predictions to compare with labels

# %%
tokenizer = AutoTokenizer.from_pretrained("bigbird/output/ml/epoch-5")
model = BigBirdForSequenceClassification.from_pretrained("bigbird/output/ml/epoch-5")

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)
device
# Out:
# device(type='cuda')

# %%
def tokenization(batched_text):
    return tokenizer(batched_text['text'], padding = "longest", truncation=True, max_length = 2048)

def m3_predict_probs(sample):
    dataset = pd.DataFrame(sample, columns=['text'])
    dataset = Dataset.from_pandas(dataset)
    dataset = dataset.map(tokenization, batched=True, batch_size=2, remove_columns=['text'])
    dataset.set_format('torch', columns=['input_ids', 'attention_mask'])

    loader = DataLoader(dataset, batch_size=2)
    probs = None

    for batch in loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        outputs = model(input_ids, attention_mask=attention_mask)
        outputs = outputs.logits.sigmoid().cpu().detach().numpy()
        probs = outputs if probs is None else np.concatenate((probs, outputs))
        
    return probs

# %%
bb_probs = m3_predict_probs(df.text.tolist())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=27421.0), HTML(value='')))
# /data-imperial/lib/python3.9/site-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /opt/conda/conda-bld/pytorch_1623448238472/work/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# Attention type 'block_sparse' is not possible if sequence_length: 693 <= num global tokens: 2 * config.block_size + min. num sliding tokens: 3 * config.block_size + config.num_random_blocks * config.block_size + additional buffer: config.num_random_blocks * config.block_size = 704 with config.block_size = 64, config.num_random_blocks = 3.Changing attention type to 'original_full'...

# %%
bb_probs_df = pd.DataFrame(bb_probs, 
                           columns = ['desire_bb', 'intent_bb', 'capability_bb', 'timeframe_bb',
                                      'substance_bb', 'depressed_bb', 'self_harm_bb', 'anxiety_bb', 
                                      'helpful_bb'], 
                           index=df.index)

# %%
df = pd.concat([df, bb_probs_df], axis=1, join='inner')
pickle.dump(df, open('saved/multilabel_text_with_preds.pickle', 'wb'))

# %% [markdown]
# #### Selecting conversations

# %%
df = pickle.load(open('saved/multilabel_text_with_preds.pickle', 'rb'))

# %%
no_text = df.loc[:, df.columns[1:]] > 0.5
no_text
# Out:
#                                                     desire  intent  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...   False   False
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...   False   False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...   False   False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...   False   False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...   False   False
# ...                                                    ...     ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...   False   False
# fff856ea88444fb982e9072ab257985996f668ab959b497...   False   False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...   False   False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...    True    True
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...   False   False
#
#                                                     capability  timeframe  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...       False      False
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...       False      False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...       False      False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...       False      False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...       False      False
# ...                                                        ...        ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...       False      False
# fff856ea88444fb982e9072ab257985996f668ab959b497...       False      False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...       False      False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...       False      False
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...       False      False
#
#                                                     substance  depressed  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...      False      False
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...      False      False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...      False      False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...      False      False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...      False      False
# ...                                                       ...        ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...      False      False
# fff856ea88444fb982e9072ab257985996f668ab959b497...      False       True
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...      False      False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...      False      False
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...      False      False
#
#                                                     self_harm  anxiety  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...      False     True
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...      False    False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...      False    False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...      False    False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...      False    False
# ...                                                       ...      ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...      False     True
# fff856ea88444fb982e9072ab257985996f668ab959b497...      False     True
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...      False    False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...      False     True
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...      False    False
#
#                                                     helpful  desire_rf  ...  \
# conversation_id                                                         ...
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...     True      False  ...
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...     True      False  ...
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...     True      False  ...
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...    False      False  ...
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...     True      False  ...
# ...                                                     ...        ...  ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...     True      False  ...
# fff856ea88444fb982e9072ab257985996f668ab959b497...     True      False  ...
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...     True      False  ...
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...     True      False  ...
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...     True      False  ...
#
#                                                     helpful_rf  desire_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...        True      False
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...        True       True
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...        True      False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...        True      False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...        True      False
# ...                                                        ...        ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...        True      False
# fff856ea88444fb982e9072ab257985996f668ab959b497...        True      False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...        True      False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...        True       True
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...        True      False
#
#                                                     intent_bb  capability_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...      False          False
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...      False          False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...      False          False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...      False          False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...      False          False
# ...                                                       ...            ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...      False          False
# fff856ea88444fb982e9072ab257985996f668ab959b497...      False          False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...      False          False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...      False          False
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...      False          False
#
#                                                     timeframe_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...         False
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...         False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...         False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...         False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...         False
# ...                                                          ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...         False
# fff856ea88444fb982e9072ab257985996f668ab959b497...         False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...         False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...         False
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...         False
#
#                                                     substance_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...         False
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...         False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...         False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...         False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...         False
# ...                                                          ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...         False
# fff856ea88444fb982e9072ab257985996f668ab959b497...         False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...         False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...         False
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...         False
#
#                                                     depressed_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...         False
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...         False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...         False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...         False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...          True
# ...                                                          ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...         False
# fff856ea88444fb982e9072ab257985996f668ab959b497...          True
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...         False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...         False
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...         False
#
#                                                     self_harm_bb  anxiety_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...         False        True
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...         False       False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...         False       False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...         False       False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...         False       False
# ...                                                          ...         ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...         False        True
# fff856ea88444fb982e9072ab257985996f668ab959b497...         False        True
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...         False       False
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...         False        True
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...         False        True
#
#                                                     helpful_bb
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...        True
# 000111a50f8f14341da6bd35c5574133cf991fd021774f7...        True
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...        True
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...       False
# 0002be67f4de3c255e297f52dbafc9649ce3ae5fcb325ab...        True
# ...                                                        ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...        True
# fff856ea88444fb982e9072ab257985996f668ab959b497...        True
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...        True
# fffc63d0b0ac2bb66ee4c67df1367215b90a54004eb7326...        True
# fffdd220cd7d4fba2ded74a07ba0170383d0fce3ee21ab4...        True
#
# [54842 rows x 27 columns]

# %% [markdown]
# #### Selecting individual conversations

# %%
no_text[['wrong_bb', 'wrong_rf']] = 0
for i in tqdm(no_text.index):
    bb_count = 0
    rf_count = 0
    for j in range(9):
        rf_count += 1 if no_text.loc[i, no_text.columns[j]] != no_text.loc[i, no_text.columns[j+9]] else 0
        bb_count += 1 if no_text.loc[i, no_text.columns[j]] != no_text.loc[i, no_text.columns[j+18]] else 0
    no_text.loc[i, ['wrong_bb', 'wrong_rf']] = [bb_count, rf_count]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=54842.0), HTML(value='')))

# %% [markdown]
# #### Many wrongly predicted labels

# %%
text = df.loc['1a199f93fcd83ccc410c12957ca213c9c95cfb1f6ed93341f5c6ead288fc01e9', 'text']

# %%
no_text[(no_text['wrong_bb'] == 5)]
# Out:
#                                                     desire  intent  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...   False   False
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...   False   False
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...    True   False
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...   False   False
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...    True    True
# ...                                                    ...     ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...    True    True
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...   False   False
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...    True    True
# feda078f509317e658efd6035859ba01593740a358eb42a...   False   False
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...    True    True
#
#                                                     capability  timeframe  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...       False      False
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...       False      False
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...       False      False
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...       False      False
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...        True       True
# ...                                                        ...        ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...        True       True
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...       False      False
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...        True       True
# feda078f509317e658efd6035859ba01593740a358eb42a...       False      False
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...        True       True
#
#                                                     substance  depressed  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...      False      False
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...      False      False
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...      False       True
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...      False       True
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...      False      False
# ...                                                       ...        ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...      False      False
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...      False      False
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...      False       True
# feda078f509317e658efd6035859ba01593740a358eb42a...      False       True
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...      False      False
#
#                                                     self_harm  anxiety  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...       True    False
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...      False     True
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...       True    False
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...      False    False
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...      False    False
# ...                                                       ...      ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...      False    False
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...      False    False
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...      False    False
# feda078f509317e658efd6035859ba01593740a358eb42a...      False     True
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...       True     True
#
#                                                     helpful  desire_rf  ...  \
# conversation_id                                                         ...
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...    False      False  ...
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...     True      False  ...
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...    False      False  ...
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...     True      False  ...
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...     True      False  ...
# ...                                                     ...        ...  ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...    False      False  ...
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...     True      False  ...
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...     True      False  ...
# feda078f509317e658efd6035859ba01593740a358eb42a...     True      False  ...
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...     True      False  ...
#
#                                                     intent_bb  capability_bb  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...       True           True
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...       True           True
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...       True           True
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...       True           True
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...      False          False
# ...                                                       ...            ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...      False          False
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...       True           True
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...      False          False
# feda078f509317e658efd6035859ba01593740a358eb42a...       True           True
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...       True          False
#
#                                                     timeframe_bb  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...          True
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...         False
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...         False
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...         False
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...         False
# ...                                                          ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...         False
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...          True
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...         False
# feda078f509317e658efd6035859ba01593740a358eb42a...         False
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...         False
#
#                                                     substance_bb  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...         False
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...         False
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...         False
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...         False
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...         False
# ...                                                          ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...         False
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...         False
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...         False
# feda078f509317e658efd6035859ba01593740a358eb42a...         False
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...         False
#
#                                                     depressed_bb  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...         False
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...         False
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...         False
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...         False
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...         False
# ...                                                          ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...          True
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...         False
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...         False
# feda078f509317e658efd6035859ba01593740a358eb42a...         False
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...          True
#
#                                                     self_harm_bb  anxiety_bb  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...         False       False
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...         False       False
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...         False       False
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...          True       False
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...          True       False
# ...                                                          ...         ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...         False        True
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...         False       False
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...         False       False
# feda078f509317e658efd6035859ba01593740a358eb42a...         False       False
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...         False       False
#
#                                                     helpful_bb  wrong_bb  \
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...       False         5
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...       False         5
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...        True         5
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...        True         5
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...       False         5
# ...                                                        ...       ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...       False         5
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...       False         5
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...       False         5
# feda078f509317e658efd6035859ba01593740a358eb42a...        True         5
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...        True         5
#
#                                                     wrong_rf
# conversation_id
# 0278a617c708b238fb878b5ee945d31b0970d655e93e801...         2
# 063d510135e062d5082a0937df1c79c38ef486d283c7d35...         1
# 0d14e3028605cb6e209505ea0670b7211706a36a3d647bb...         4
# 0ea08e6982c8aff1580cba5b809c23210e6ef3f43d55cd6...         1
# 1568c3fcff956ba1b707f4b913f1578edc3bb88e76bd81a...         4
# ...                                                      ...
# fa688e653d9ec1c83f92f28e08ef3806696ab6a2b2abd83...         5
# faa9e3dda0c7e349885a1dd0fed4ba1db966fb8a9835e64...         0
# fbf35f84829f73e54e2adaac4cfb01ad9ea66ac9de2dff1...         5
# feda078f509317e658efd6035859ba01593740a358eb42a...         2
# ff5c4bb6b2e08ae0477a597e57c9640542baaf91aeb6efc...         6
#
# [94 rows x 29 columns]

# %%
bb_fp = df.loc['af30982a452168b259508a70b7a89382afc7a3949f8003cd1c4095862b7e2271', 'text']
pickle.dump(bb_fp, open("saved/text_samples/sample7.pickle", "wb"))

# %%
bb_fp2 = df.loc['1d23d1780ab2e03aee8a38c93852bbbcb837fde18b917a25becd80f18698198d', 'text']
pickle.dump(bb_fp2, open("saved/text_samples/sample8.pickle", "wb"))

# %% [markdown]
# #### All correctly predicted labels

# %%
no_text[(no_text['wrong_bb'] == 0)]
# Out:
#                                                     desire  intent  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...   False   False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...   False   False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...   False   False
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...   False   False
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...   False   False
# ...                                                    ...     ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...   False   False
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...   False   False
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...   False   False
# fff856ea88444fb982e9072ab257985996f668ab959b497...   False   False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...   False   False
#
#                                                     capability  timeframe  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...       False      False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...       False      False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...       False      False
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...       False      False
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...       False      False
# ...                                                        ...        ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...       False      False
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...       False      False
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...       False      False
# fff856ea88444fb982e9072ab257985996f668ab959b497...       False      False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...       False      False
#
#                                                     substance  depressed  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...      False      False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...      False      False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...      False      False
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...      False       True
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...      False      False
# ...                                                       ...        ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...      False       True
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...      False      False
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...      False      False
# fff856ea88444fb982e9072ab257985996f668ab959b497...      False       True
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...      False      False
#
#                                                     self_harm  anxiety  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...      False     True
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...      False    False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...      False    False
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...      False     True
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...      False    False
# ...                                                       ...      ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...      False    False
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...      False    False
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...      False     True
# fff856ea88444fb982e9072ab257985996f668ab959b497...      False     True
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...      False    False
#
#                                                     helpful  desire_rf  ...  \
# conversation_id                                                         ...
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...     True      False  ...
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...     True      False  ...
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...    False      False  ...
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...     True      False  ...
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...     True      False  ...
# ...                                                     ...        ...  ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...     True      False  ...
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...     True      False  ...
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...     True      False  ...
# fff856ea88444fb982e9072ab257985996f668ab959b497...     True      False  ...
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...     True      False  ...
#
#                                                     intent_bb  capability_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...      False          False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...      False          False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...      False          False
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...      False          False
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...      False          False
# ...                                                       ...            ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...      False          False
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...      False          False
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...      False          False
# fff856ea88444fb982e9072ab257985996f668ab959b497...      False          False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...      False          False
#
#                                                     timeframe_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...         False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...         False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...         False
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...         False
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...         False
# ...                                                          ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...         False
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...         False
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...         False
# fff856ea88444fb982e9072ab257985996f668ab959b497...         False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...         False
#
#                                                     substance_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...         False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...         False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...         False
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...         False
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...         False
# ...                                                          ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...         False
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...         False
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...         False
# fff856ea88444fb982e9072ab257985996f668ab959b497...         False
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...         False
#
#                                                     depressed_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...         False
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...         False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...         False
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...          True
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...         False
# ...                                                          ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...          True
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...         False
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...         False
# fff856ea88444fb982e9072ab257985996f668ab959b497...          True
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...         False
#
#                                                     self_harm_bb  anxiety_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...         False        True
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...         False       False
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...         False       False
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...         False        True
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...         False       False
# ...                                                          ...         ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...         False       False
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...         False       False
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...         False        True
# fff856ea88444fb982e9072ab257985996f668ab959b497...         False        True
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...         False       False
#
#                                                     helpful_bb  wrong_bb  \
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...        True         0
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...        True         0
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...       False         0
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...        True         0
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...        True         0
# ...                                                        ...       ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...        True         0
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...        True         0
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...        True         0
# fff856ea88444fb982e9072ab257985996f668ab959b497...        True         0
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...        True         0
#
#                                                     wrong_rf
# conversation_id
# 000087ec0f14337a6124ed7aa770cee1e29fcc9be90ff4c...         1
# 00019c048486c231e7ea91371968c7e4b0349f04d1b1fac...         0
# 0001bbd8070263101e9a7845ce1f9b38895a35ba29cab17...         1
# 0003913c5c6bacb2e1b5711feaf76cb6598f3074fae7956...         2
# 0004daf966198dfa1885ee66496037f3afdb928bc2a6549...         0
# ...                                                      ...
# fff63c45041982c732ba2f3635f977310edfc1fce00dca0...         1
# fff7b6e089337e63c654a13b65a699012bf5968ee5dbd75...         0
# fff7fc9e8ce4b166533fc67b04fe079cce4327bda6a6ee8...         1
# fff856ea88444fb982e9072ab257985996f668ab959b497...         2
# fffad4b870833f3cae3410c726f5e921fefae49fe6602f9...         0
#
# [25645 rows x 29 columns]

# %%
rf_fn = df.loc['28613325d87170b554f2055c3c6213c22afa2d204974bdc24342e9f094723c85', 'text']
pickle.dump(rf_fn, open('saved/text_samples/sample9.pickle', 'wb'))

# %% [markdown]
# ## Texts for Aggregate Explanations

# %%
def get_samples(df, per_group, random_state=42): 
    labels = list(df.columns)
    samples = df.groupby(labels)\
                .apply(lambda x: x.sample(per_group, random_state=random_state))\
                .reset_index(level=labels, drop=True)
    return samples

# %% [markdown]
# #### Substance abuse

# %%
random.seed(42)
correct_pred = no_text.query("substance == substance_bb")
sample_index = random.sample(list(correct_pred[correct_pred.substance==1].index), 100)
labelled_text = pd.DataFrame(df.loc[sample_index, ['text']])
pickle.dump(labelled_text, open("saved/substance/100_text_samples.pickle", "wb"))

# %% [markdown]
# #### Depression and Anxiety and Suicidal Desire

# %%
correct_pred = no_text.query('depressed == depressed_bb and anxiety == anxiety_bb and desire == desire_bb')
samples = get_samples(correct_pred[['depressed', 'anxiety', 'desire']], 12)
labelled_text = pd.concat([samples, df.text], axis=1, join='inner')

# %%
pickle.dump(labelled_text, open("saved/anxiety/96_text_samples.pickle", "wb"))

# %% [markdown]
# #### Suicidal capability risk

# %%
random.seed(42)
cap_index = random.sample(list(capability.index), 100)
cap_samples = pd.DataFrame(df.loc[cap_index, ['text']])
pickle.dump(cap_samples, open("saved/capability/100_text_samples.pickle", "wb"))

# %%
tf_index = random.sample(list(timeframe.index), 102)
tf_samples = pd.DataFrame(df.loc[tf_index, ['text']])
tf_samples = tf_samples.drop(index=pd.concat([cap_samples, tf_samples], axis=1, join='inner').index)
pickle.dump(tf_samples, open("saved/timeframe/100_text_samples.pickle", "wb"))

# %%
suicide = no_text.query("capability==capability_bb and timeframe==timeframe_bb and desire==desire_bb and intent==intent_bb")
samples = get_samples(suicide[['desire', 'intent', 'capability', 'timeframe']], 20)
labelled_text = pd.concat([samples, df.text], axis=1, join='inner')

# %%
labelled_text[labelled_text.columns[:-1]].value_counts()
# Out:
# desire  intent  capability  timeframe
# False   False   False       False        20
# True    False   False       False        20
#         True    False       False        20
#                 True        False        20
#                             True         20
# dtype: int64

# %%
pickle.dump(labelled_text, open("saved/suicide/100_text_samples.pickle", "wb"))

# %% [markdown]
# #### Helpfulness

# %%
helpful = no_text.loc[no_text.helpful & no_text.helpful_bb]
unhelpful = no_text.loc[~no_text.helpful & ~no_text.helpful_bb]

# %%
random.seed(42)
indexes = random.sample(list(helpful.index), 50)
indexes.extend(random.sample(list(unhelpful.index), 50))
samples = pd.DataFrame(df.loc[indexes, ['text', 'helpful']])
pickle.dump(samples, open("saved/helpful/100_text_samples.pickle", "wb"))

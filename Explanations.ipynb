# %%
import datasets
import os
import pickle
import plotly
import random
import re
import scipy
import seaborn as sns
import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from lime import lime_text
from lime.lime_text import LimeTextExplainer

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

from termcolor import colored

from tqdm.auto import tqdm, trange

# %%
def aggregate_exps(exp_list):
    keys = pd.Series([i[0] for i in exp_list])
    attributions = pd.DataFrame(index=keys.unique())
    attributions['value'] = 0
    attributions['count'] = 0
    
    for i in tqdm(exp_list): 
        index, value = i
        attributions.loc[index, 'value'] += value
        attributions.loc[index, 'count'] += 1
        
    attributions['average'] = attributions['value'] / attributions['count']
    attributions['abs_average'] = abs(attributions['average'])
    return attributions

# %% [markdown]
# ## Suicidal Capability and Timeframe

# %%
cap = aggregate_exps(pickle.load(open("saved/capability/exp_raw.pickle", "rb")))
tf = aggregate_exps(pickle.load(open("saved/timeframe/exp_raw.pickle", "rb")))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))

# %%
print(f"Capability features: {cap.shape[0]}")
print(f"Timeframe features: {tf.shape[0]}")
# Out:
# Capability features: 1925
# Timeframe features: 1858

# %%
print(f"Overlap: {len(set(cap.index) & set(tf.index))}")
# Out:
# Overlap: 1146

# %%
cap[cap['abs_average'] > 0.04].sort_values("count", ascending=False)[:25]
# Out:
#               value  count   average  abs_average
# you       10.093004    100  0.100930     0.100930
# have       6.111871     91  0.067163     0.067163
# to         4.186618     84  0.049841     0.049841
# when       7.177573     78  0.092020     0.092020
# this       3.362069     78  0.043103     0.043103
# life       4.916820     74  0.066444     0.066444
# plan       4.011106     73  0.054947     0.054947
# the        2.881202     71  0.040580     0.040580
# safe       2.924846     67  0.043654     0.043654
# suicidal   4.427445     64  0.069179     0.069179
# end        4.654659     63  0.073883     0.073883
# would      2.642474     58  0.045560     0.045560
# time       2.850107     57  0.050002     0.050002
# take       3.386967     54  0.062722     0.062722
# suicide    3.417462     51  0.067009     0.067009
# pills      4.951578     38  0.130305     0.130305
# overdose   3.255273     32  0.101727     0.101727
# kill       2.156721     30  0.071891     0.071891
# access     0.945108     21  0.045005     0.045005
# planned    1.232770     19  0.064883     0.064883
# off        1.090681     19  0.057404     0.057404
# tomorrow   0.843139     17  0.049596     0.049596
# ending     0.742739     16  0.046421     0.046421
# carry      1.137163     15  0.075811     0.075811
# hang       2.330877     15  0.155392     0.155392

# %%
cap[cap['count'] > 5].sort_values("abs_average", ascending=False)[:25]
# Out:
#                  value  count   average  abs_average
# railings      0.247715      1  0.247715     0.247715
# suffocate     0.199962      1  0.199962     0.199962
# hang          2.330877     15  0.155392     0.155392
# paracetamol   0.997332      7  0.142476     0.142476
# railway       0.138242      1  0.138242     0.138242
# tracks        0.270167      2  0.135083     0.135083
# pills         4.951578     38  0.130305     0.130305
# vehicle       0.128947      1  0.128947     0.128947
# 7am           0.126959      1  0.126959     0.126959
# bedroom       0.112313      1  0.112313     0.112313
# cupboard      0.656509      6  0.109418     0.109418
# nearest       0.105631      1  0.105631     0.105631
# infront       0.207756      2  0.103878     0.103878
# ligature      0.309585      3  0.103195     0.103195
# havnt        -0.102994      1 -0.102994     0.102994
# blades       -0.102700      1 -0.102700     0.102700
# road          0.716620      7  0.102374     0.102374
# ligatures     0.102033      1  0.102033     0.102033
# overdose      3.255273     32  0.101727     0.101727
# you          10.093004    100  0.100930     0.100930
# knife         0.387853      4  0.096963     0.096963
# when          7.177573     78  0.092020     0.092020
# shed          0.089550      1  0.089550     0.089550
# jumping       0.973399     11  0.088491     0.088491
# near          1.059080     12  0.088257     0.088257

# %%
tf[tf['count'] > 5].sort_values("abs_average", ascending=False)[:25]
# Out:
#                 value  count   average  abs_average
# paracetamol  1.756677     17  0.103334     0.103334
# you          9.466064    100  0.094661     0.094661
# pills        2.872949     31  0.092676     0.092676
# tablets      2.147469     27  0.079536     0.079536
# ambulance    0.582114      8  0.072764     0.072764
# when         5.445176     76  0.071647     0.071647
# train        0.419790      6  0.069965     0.069965
# jumping      0.747309     11  0.067937     0.067937
# overdose     2.626548     40  0.065664     0.065664
# tomorrow     1.413535     22  0.064252     0.064252
# rope         0.500872      8  0.062609     0.062609
# end          4.149544     68  0.061023     0.061023
# die          1.538251     28  0.054938     0.054938
# life         4.210907     78  0.053986     0.053986
# have         4.940845     93  0.053127     0.053127
# overdosing   0.357596      7  0.051085     0.051085
# knife        0.402094      8  0.050262     0.050262
# 999          2.656873     54  0.049201     0.049201
# kill         1.744781     36  0.048466     0.048466
# downstairs   0.327869      7  0.046838     0.046838
# planned      1.203011     26  0.046270     0.046270
# time         3.334910     75  0.044465     0.044465
# off          0.699113     16  0.043695     0.043695
# plan         3.185289     74  0.043044     0.043044
# hanging      0.247754      6  0.041292     0.041292

# %% [markdown]
# ## Helpfulness

# %%
exp_list = pickle.load(open("saved/helpful/exp_raw.pickle", "rb"))
og = pickle.load(open("saved/helpful/100_text_samples.pickle", "rb"))
attributions = aggregate_exps(exp_list)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))

# %% [markdown]
# ## Anxiety, Depressed, Suicidal

# %%
anxiety = aggregate_exps(pickle.load(open("saved/anxiety/exp_raw.pickle", "rb")))
depressed = aggregate_exps(pickle.load(open("saved/anxiety/depressed/exp_raw.pickle", "rb")))
suicide = aggregate_exps(pickle.load(open("saved/anxiety/suicide/exp_raw.pickle", "rb")))

# %%
common = pd.concat([anxiety, depressed, suicide], axis=1, join='inner')
common = common.drop(columns=['value'])
common.columns = ['a_count', 'a_average', 'a_abs_average', 
                  'd_count', 'd_average', 'd_abs_average', 
                  's_count', 's_average', 's_abs_average']

print(f"Anxiety and Depression overlap: {len(set(anxiety.index) & set(depressed.index))}")
print(f"Anxiety and Suicide overlap: {len(set(anxiety.index) & set(suicide.index))}")
print(f"Depression and Suicide overlap: {len(set(depressed.index) & set(suicide.index))}")
print(f"Common features: {common.shape[0]}")
# Out:
# Anxiety and Depression overlap: 1520
# Anxiety and Suicide overlap: 1450
# Depression and Suicide overlap: 1455
# Common features: 1224

# %%
common.sort_values('a_abs_average', ascending=False)[:25]
# Out:
#                 a_count  a_average  a_abs_average  d_count  d_average  \
# anxiety              30   0.206459       0.206459       28  -0.071723
# disabled              1  -0.192211       0.192211        1  -0.063499
# trans                 1  -0.176880       0.176880        1  -0.266226
# sexuality             1  -0.154350       0.154350        1  -0.006777
# bullying              1  -0.149778       0.149778        1  -0.137102
# anxieties             1   0.118987       0.118987        1  -0.087299
# stressed              5   0.098432       0.098432        3  -0.038408
# visions               1   0.089294       0.089294        1  -0.009533
# abusing               3  -0.088330       0.088330        3  -0.015711
# dread                 1   0.082166       0.082166        1  -0.008815
# weed                  2  -0.080546       0.080546        2  -0.027097
# anxious              13   0.077452       0.077452       13  -0.036406
# transgender           1  -0.072699       0.072699        1  -0.055562
# hallucinations        1  -0.071726       0.071726        1  -0.006783
# nerves                1   0.069149       0.069149        1  -0.034142
# wrists                1  -0.064656       0.064656        1  -0.033427
# sucidial              1  -0.064480       0.064480        1  -0.058341
# nervous               4   0.060623       0.060623        2  -0.033765
# virus                 3  -0.060399       0.060399        3  -0.023037
# bereavement           1  -0.060001       0.060001        1  -0.060349
# bullied               2  -0.058855       0.058855        2  -0.050070
# noose                 2  -0.057761       0.057761        2  -0.042272
# panicky               3   0.057017       0.057017        3  -0.009077
# ligature              1  -0.056940       0.056940        1  -0.064197
# cyanide               1  -0.055820       0.055820        1  -0.019128
#
#                 d_abs_average  s_count  s_average  s_abs_average
# anxiety              0.071723       22  -0.027992       0.027992
# disabled             0.063499        1   0.000056       0.000056
# trans                0.266226        1  -0.006672       0.006672
# sexuality            0.006777        1   0.000113       0.000113
# bullying             0.137102        1  -0.002775       0.002775
# anxieties            0.087299        1   0.000258       0.000258
# stressed             0.038408        5  -0.009607       0.009607
# visions              0.009533        1  -0.163240       0.163240
# abusing              0.015711        3   0.005822       0.005822
# dread                0.008815        1   0.001644       0.001644
# weed                 0.027097        2  -0.029776       0.029776
# anxious              0.036406        7  -0.009038       0.009038
# transgender          0.055562        1  -0.015694       0.015694
# hallucinations       0.006783        1   0.003114       0.003114
# nerves               0.034142        1  -0.009227       0.009227
# wrists               0.033427        1   0.097497       0.097497
# sucidial             0.058341        1   0.074663       0.074663
# nervous              0.033765        1  -0.022860       0.022860
# virus                0.023037        1  -0.002426       0.002426
# bereavement          0.060349        1  -0.000512       0.000512
# bullied              0.050070        1  -0.000072       0.000072
# noose                0.042272        2   0.116510       0.116510
# panicky              0.009077        2  -0.001192       0.001192
# ligature             0.064197        1   0.054751       0.054751
# cyanide              0.019128        1   0.085432       0.085432

# %%
common.sort_values('d_abs_average', ascending=False)[:25]
# Out:
#                  a_count  a_average  a_abs_average  d_count  d_average  \
# depressed              7  -0.043971       0.043971        8   0.267781
# trans                  1  -0.176880       0.176880        1  -0.266226
# depressive             3  -0.052485       0.052485        3   0.264903
# depression            16  -0.044620       0.044620       17   0.230524
# bullying               1  -0.149778       0.149778        1  -0.137102
# agressive              1  -0.050654       0.050654        1  -0.096177
# despair                1  -0.011209       0.011209        1   0.091552
# anxieties              1   0.118987       0.118987        1  -0.087299
# sadness                4  -0.048359       0.048359        5   0.078535
# anxiety               30   0.206459       0.206459       28  -0.071723
# cutting               12  -0.051452       0.051452       12  -0.069747
# cupboard               1  -0.034437       0.034437        1  -0.068053
# low                   18  -0.021782       0.021782       32   0.067802
# antidepressants        2  -0.007205       0.007205        6   0.066875
# ligature               1  -0.056940       0.056940        1  -0.064197
# mood                   6  -0.009952       0.009952       12   0.064015
# disabled               1  -0.192211       0.192211        1  -0.063499
# unhappy                2   0.008988       0.008988        3   0.061363
# bereavement            1  -0.060001       0.060001        1  -0.060349
# depressants            3   0.022872       0.022872        3   0.058598
# sucidial               1  -0.064480       0.064480        1  -0.058341
# pressure               4   0.053258       0.053258        2  -0.055573
# transgender            1  -0.072699       0.072699        1  -0.055562
# agrophobic             1  -0.043898       0.043898        1  -0.051325
# pandemic               3  -0.051755       0.051755        3  -0.050525
#
#                  d_abs_average  s_count  s_average  s_abs_average
# depressed             0.267781        6  -0.017329       0.017329
# trans                 0.266226        1  -0.006672       0.006672
# depressive            0.264903        1   0.006888       0.006888
# depression            0.230524       12   0.010370       0.010370
# bullying              0.137102        1  -0.002775       0.002775
# agressive             0.096177        1  -0.017467       0.017467
# despair               0.091552        1   0.010101       0.010101
# anxieties             0.087299        1   0.000258       0.000258
# sadness               0.078535        2  -0.007920       0.007920
# anxiety               0.071723       22  -0.027992       0.027992
# cutting               0.069747        8  -0.002843       0.002843
# cupboard              0.068053        1   0.043028       0.043028
# low                   0.067802       14   0.000944       0.000944
# antidepressants       0.066875        3  -0.002921       0.002921
# ligature              0.064197        1   0.054751       0.054751
# mood                  0.064015        7   0.005012       0.005012
# disabled              0.063499        1   0.000056       0.000056
# unhappy               0.061363        2  -0.023971       0.023971
# bereavement           0.060349        1  -0.000512       0.000512
# depressants           0.058598        2   0.003432       0.003432
# sucidial              0.058341        1   0.074663       0.074663
# pressure              0.055573        2  -0.008094       0.008094
# transgender           0.055562        1  -0.015694       0.015694
# agrophobic            0.051325        1  -0.029699       0.029699
# pandemic              0.050525        2  -0.000760       0.000760

# %%
common.sort_values('s_abs_average', ascending=False)[:25]
# Out:
#              a_count  a_average  a_abs_average  d_count  d_average  \
# visions            1   0.089294       0.089294        1  -0.009533
# suicidal          44  -0.049901       0.049901       43  -0.022637
# noose              2  -0.057761       0.057761        2  -0.042272
# suicide           43  -0.021415       0.021415       52   0.011016
# drown              1  -0.018196       0.018196        1   0.010227
# hang               8  -0.037742       0.037742        6  -0.027148
# window             1  -0.012190       0.012190        1  -0.005309
# wrists             1  -0.064656       0.064656        1  -0.033427
# you               93  -0.030458       0.030458       80   0.003247
# kill              28  -0.027611       0.027611       31  -0.026655
# cyanide            1  -0.055820       0.055820        1  -0.019128
# end               48  -0.029656       0.029656       44  -0.019641
# sucidial           1  -0.064480       0.064480        1  -0.058341
# die               24  -0.028410       0.028410       20  -0.021456
# Suicidal           6  -0.040471       0.040471        5  -0.036527
# life              65  -0.025152       0.025152       47  -0.003793
# anger              1   0.002168       0.002168        1  -0.020027
# attempt            3  -0.007035       0.007035        1  -0.022521
# overdose          13  -0.024866       0.024866       10  -0.015620
# ending            24  -0.012915       0.012915       17  -0.017025
# supplies           1  -0.016879       0.016879        1   0.011484
# painkillers        1  -0.052665       0.052665        1  -0.015841
# ligature           1  -0.056940       0.056940        1  -0.064197
# plan              40  -0.009629       0.009629       32   0.001342
# paracetamol        5  -0.024911       0.024911        5  -0.023292
#
#              d_abs_average  s_count  s_average  s_abs_average
# visions           0.009533        1  -0.163240       0.163240
# suicidal          0.022637       50   0.152345       0.152345
# noose             0.042272        2   0.116510       0.116510
# suicide           0.011016       56   0.116248       0.116248
# drown             0.010227        1   0.113709       0.113709
# hang              0.027148        8   0.107106       0.107106
# window            0.005309        1   0.104682       0.104682
# wrists            0.033427        1   0.097497       0.097497
# you               0.003247       99   0.095130       0.095130
# kill              0.026655       36   0.088276       0.088276
# cyanide           0.019128        1   0.085432       0.085432
# end               0.019641       52   0.083855       0.083855
# sucidial          0.058341        1   0.074663       0.074663
# die               0.021456       26   0.072024       0.072024
# Suicidal          0.036527        6   0.071255       0.071255
# life              0.003793       66   0.067861       0.067861
# anger             0.020027        1  -0.067252       0.067252
# attempt           0.022521        2   0.060042       0.060042
# overdose          0.015620       14   0.059641       0.059641
# ending            0.017025       24   0.056760       0.056760
# supplies          0.011484        1   0.056671       0.056671
# painkillers       0.015841        1   0.056461       0.056461
# ligature          0.064197        1   0.054751       0.054751
# plan              0.001342       63   0.050654       0.050654
# paracetamol       0.023292        5   0.046993       0.046993

# %% [markdown]
# ## Suicide Risk

# %%
desire = aggregate_exps(pickle.load(open("saved/suicide/desire/exp_raw.pickle", "rb")))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))

# %%
intent = aggregate_exps(pickle.load(open("saved/suicide/intent/exp_raw.pickle", "rb")))
capability = aggregate_exps(pickle.load(open("saved/suicide/capability/exp_raw.pickle", "rb")))
timeframe = aggregate_exps(pickle.load(open("saved/suicide/timeframe/exp_raw.pickle", "rb")))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))

# %%
print(f"desire: {desire.shape[0]}")
print(f"intent: {intent.shape[0]}")
print(f"capability: {capability.shape[0]}")
print(f"timeframe: {timeframe.shape[0]}")
# Out:
# desire: 2030
# intent: 2004
# capability: 1979
# timeframe: 1965

# %%
common = pd.concat([desire, intent, capability, timeframe], axis=1, join='inner')
common = common.drop(columns=['value'])
common.columns = ['d_count', 'd_average', 'd_abs_average', 
                  'i_count', 'i_average', 'i_abs_average', 
                  'c_count', 'c_average', 'c_abs_average', 
                  't_count', 't_average', 't_abs_average']
print(f"overlap: {common.shape[0]}")
# Out:
# overlap: 1138

# %%
print(f"desire x intent: {len(set(desire.index) & set(intent.index))}")
print(f"desire x capability: {len(set(desire.index) & set(capability.index))}")
print(f"desire x timeframe: {len(set(desire.index) & set(timeframe.index))}")
print("\n")
print(f"intent x capability: {len(set(intent.index) & set(capability.index))}")
print(f"intent x timeframe: {len(set(intent.index) & set(timeframe.index))}")
print("\n")
print(f"capability x timeframe: {len(set(capability.index) & set(timeframe.index))}")
print("\n")
print(f"desire x intent x capability: {len(set(desire.index) & set(intent.index) & set(capability.index))}")
print(f"desire x intent x timeframe: {len(set(desire.index) & set(intent.index) & set(timeframe.index))}")
print(f"desire x capability x timeframe: {len(set(desire.index) & set(capability.index) & set(timeframe.index))}")
print("\n")
print(f"timeframe x intent x capability: {len(set(timeframe.index) & set(intent.index) & set(capability.index))}")
# Out:
# desire x intent: 1469
# desire x capability: 1455
# desire x timeframe: 1453
#
#
# intent x capability: 1475
# intent x timeframe: 1455
#
#
# capability x timeframe: 1470
#
#
# desire x intent x capability: 1251
# desire x intent x timeframe: 1239
# desire x capability x timeframe: 1245
#
#
# timeframe x intent x capability: 1259

# %%
desire.sort_values('abs_average', ascending=False)[:25]
# Out:
#              value  count   average  abs_average
# visions  -0.171154      1 -0.171154     0.171154
# suicidal  7.803215     50  0.156064     0.156064
# suicide   6.600445     56  0.117865     0.117865
# wrists    0.115037      1  0.115037     0.115037
# noose     0.223809      2  0.111905     0.111905
# drown     0.109437      1  0.109437     0.109437
# hang      0.844506      8  0.105563     0.105563
# window    0.100955      1  0.100955     0.100955
# you       9.434922     99  0.095302     0.095302
# kill      3.137589     34  0.092282     0.092282
# cyanide   0.085254      1  0.085254     0.085254
# end       4.371721     52  0.084072     0.084072
# impulse  -0.081715      1 -0.081715     0.081715
# anger    -0.074417      1 -0.074417     0.074417
# die       1.883311     26  0.072435     0.072435
# Suicidal  0.419879      6  0.069980     0.069980
# attempt   0.137101      2  0.068551     0.068551
# nearest   0.067923      1  0.067923     0.067923
# life      4.356354     66  0.066005     0.066005
# sucidial  0.063450      1  0.063450     0.063450
# ligature  0.059985      1  0.059985     0.059985
# overdose  0.831360     14  0.059383     0.059383
# tablets   0.438849      8  0.054856     0.054856
# supplies  0.054620      1  0.054620     0.054620
# ending    1.391243     26  0.053509     0.053509

# %%
common.sort_values('d_abs_average', ascending=False)[:25]
# Out:
#           d_count  d_average  d_abs_average  i_count  i_average  \
# visions         1  -0.171154       0.171154        1  -0.016993
# suicidal       50   0.156064       0.156064       46   0.061982
# suicide        56   0.117865       0.117865       53   0.063759
# wrists          1   0.115037       0.115037        1   0.015409
# noose           2   0.111905       0.111905        2   0.171075
# drown           1   0.109437       0.109437        1   0.160206
# hang            8   0.105563       0.105563        8   0.125424
# window          1   0.100955       0.100955        1   0.158441
# you            99   0.095302       0.095302       97   0.074330
# kill           34   0.092282       0.092282       30   0.083511
# cyanide         1   0.085254       0.085254        1   0.092594
# end            52   0.084072       0.084072       51   0.080917
# impulse         1  -0.081715       0.081715        1  -0.025124
# anger           1  -0.074417       0.074417        1  -0.006733
# die            26   0.072435       0.072435       25   0.036966
# Suicidal        6   0.069980       0.069980        6   0.026206
# attempt         2   0.068551       0.068551        1   0.007042
# nearest         1   0.067923       0.067923        2   0.077400
# life           66   0.066005       0.066005       60   0.053770
# sucidial        1   0.063450       0.063450        1   0.068050
# ligature        1   0.059985       0.059985        1   0.230303
# overdose       14   0.059383       0.059383       14   0.095246
# tablets         8   0.054856       0.054856       11   0.096448
# supplies        1   0.054620       0.054620        1   0.165950
# ending         26   0.053509       0.053509       23   0.031472
#
#           i_abs_average  c_count  c_average  c_abs_average  t_count  \
# visions        0.016993        1  -0.001477       0.001477        1
# suicidal       0.061982       38   0.035058       0.035058       41
# suicide        0.063759       47   0.042325       0.042325       39
# wrists         0.015409        1   0.001770       0.001770        1
# noose          0.171075        2   0.148547       0.148547        2
# drown          0.160206        1   0.079693       0.079693        1
# hang           0.125424        8   0.091329       0.091329        8
# window         0.158441        1   0.234933       0.234933        1
# you            0.074330       98   0.056998       0.056998       97
# kill           0.083511       30   0.058304       0.058304       29
# cyanide        0.092594        1   0.075863       0.075863        1
# end            0.080917       53   0.065409       0.065409       50
# impulse        0.025124        1  -0.003995       0.003995        1
# anger          0.006733        1  -0.002781       0.002781        1
# die            0.036966       23   0.022723       0.022723       20
# Suicidal       0.026206        6   0.011777       0.011777        4
# attempt        0.007042        3   0.002792       0.002792        2
# nearest        0.077400        2   0.081366       0.081366        2
# life           0.053770       60   0.041149       0.041149       59
# sucidial       0.068050        1   0.051213       0.051213        1
# ligature       0.230303        1   0.178976       0.178976        1
# overdose       0.095246       13   0.078897       0.078897       10
# tablets        0.096448       11   0.082241       0.082241       10
# supplies       0.165950        1   0.110148       0.110148        1
# ending         0.031472       19   0.023375       0.023375       21
#
#           t_average  t_abs_average
# visions   -0.000279       0.000279
# suicidal   0.012924       0.012924
# suicide    0.013229       0.013229
# wrists     0.000266       0.000266
# noose      0.057403       0.057403
# drown      0.013002       0.013002
# hang       0.040992       0.040992
# window     0.192939       0.192939
# you        0.032360       0.032360
# kill       0.025690       0.025690
# cyanide    0.064226       0.064226
# end        0.035955       0.035955
# impulse   -0.000985       0.000985
# anger     -0.000357       0.000357
# die        0.013273       0.013273
# Suicidal   0.006663       0.006663
# attempt    0.000734       0.000734
# nearest    0.088586       0.088586
# life       0.021829       0.021829
# sucidial   0.018660       0.018660
# ligature   0.027218       0.027218
# overdose   0.026423       0.026423
# tablets    0.040658       0.040658
# supplies   0.025308       0.025308
# ending     0.008524       0.008524

# %%
timeframe.loc[set(timeframe.index) ^ set(common.index)].sort_values('abs_average', ascending=False)[:25]
# Out:
#                 value  count   average  abs_average
# vodka        0.042763      1  0.042763     0.042763
# counter      0.037476      1  0.037476     0.037476
# roads        0.035021      1  0.035021     0.035021
# 7pm          0.033798      1  0.033798     0.033798
# late         0.032901      1  0.032901     0.032901
# gown         0.030876      1  0.030876     0.030876
# miss        -0.027182      1 -0.027182     0.027182
# Overdosing  -0.025557      1 -0.025557     0.025557
# fill         0.023644      1  0.023644     0.023644
# prefer      -0.023296      1 -0.023296     0.023296
# boil         0.022914      1  0.022914     0.022914
# area         0.022719      1  0.022719     0.022719
# medical     -0.022571      1 -0.022571     0.022571
# mindfulness -0.021723      1 -0.021723     0.021723
# At          -0.021422      1 -0.021422     0.021422
# surgery     -0.021109      1 -0.021109     0.021109
# nhs         -0.020884      1 -0.020884     0.020884
# criminals   -0.020619      1 -0.020619     0.020619
# cocodamol    0.020394      1  0.020394     0.020394
# misery      -0.020318      1 -0.020318     0.020318
# brought     -0.019486      1 -0.019486     0.019486
# saved        0.019063      1  0.019063     0.019063
# virtual     -0.018796      1 -0.018796     0.018796
# Today        0.018465      1  0.018465     0.018465
# wastes      -0.018427      1 -0.018427     0.018427

# %%
timeframe.sort_values('abs_average', ascending=False)[:25]
# Out:
#                 value  count   average  abs_average
# cliffs       0.202429      1  0.202429     0.202429
# window       0.192939      1  0.192939     0.192939
# painkillers  0.140210      1  0.140210     0.140210
# cupboard     0.138545      1  0.138545     0.138545
# nearest      0.177173      2  0.088586     0.088586
# road         0.087820      1  0.087820     0.087820
# paracetamol  0.372181      5  0.074436     0.074436
# drugs        0.145319      2  0.072660     0.072660
# cyanide      0.064226      1  0.064226     0.064226
# stash        0.127063      2  0.063531     0.063531
# ibuprofen    0.120867      2  0.060434     0.060434
# noose        0.114805      2  0.057403     0.057403
# tomorrow     0.903242     16  0.056453     0.056453
# sessions    -0.055185      1 -0.055185     0.055185
# tracks       0.050422      1  0.050422     0.050422
# building     0.048102      1  0.048102     0.048102
# ambulance    0.143220      3  0.047740     0.047740
# floor        0.047709      1  0.047709     0.047709
# pole         0.045117      1  0.045117     0.045117
# breakups    -0.044969      1 -0.044969     0.044969
# vodka        0.042763      1  0.042763     0.042763
# threatening -0.042636      1 -0.042636     0.042636
# near         0.340283      8  0.042535     0.042535
# rope         0.170072      4  0.042518     0.042518
# planned      0.418893     10  0.041889     0.041889

# %%
common.sort_values('d_abs_average', ascending=False)[:25]
# Out:
#                  a_count  a_average  a_abs_average  d_count  d_average  \
# depressed              7  -0.043971       0.043971        8   0.267781
# trans                  1  -0.176880       0.176880        1  -0.266226
# depressive             3  -0.052485       0.052485        3   0.264903
# depression            16  -0.044620       0.044620       17   0.230524
# bullying               1  -0.149778       0.149778        1  -0.137102
# agressive              1  -0.050654       0.050654        1  -0.096177
# despair                1  -0.011209       0.011209        1   0.091552
# anxieties              1   0.118987       0.118987        1  -0.087299
# sadness                4  -0.048359       0.048359        5   0.078535
# anxiety               30   0.206459       0.206459       28  -0.071723
# cutting               12  -0.051452       0.051452       12  -0.069747
# cupboard               1  -0.034437       0.034437        1  -0.068053
# low                   18  -0.021782       0.021782       32   0.067802
# antidepressants        2  -0.007205       0.007205        6   0.066875
# ligature               1  -0.056940       0.056940        1  -0.064197
# mood                   6  -0.009952       0.009952       12   0.064015
# disabled               1  -0.192211       0.192211        1  -0.063499
# unhappy                2   0.008988       0.008988        3   0.061363
# bereavement            1  -0.060001       0.060001        1  -0.060349
# depressants            3   0.022872       0.022872        3   0.058598
# sucidial               1  -0.064480       0.064480        1  -0.058341
# pressure               4   0.053258       0.053258        2  -0.055573
# transgender            1  -0.072699       0.072699        1  -0.055562
# agrophobic             1  -0.043898       0.043898        1  -0.051325
# pandemic               3  -0.051755       0.051755        3  -0.050525
#
#                  d_abs_average  s_count  s_average  s_abs_average
# depressed             0.267781        6  -0.017329       0.017329
# trans                 0.266226        1  -0.006672       0.006672
# depressive            0.264903        1   0.006888       0.006888
# depression            0.230524       12   0.010370       0.010370
# bullying              0.137102        1  -0.002775       0.002775
# agressive             0.096177        1  -0.017467       0.017467
# despair               0.091552        1   0.010101       0.010101
# anxieties             0.087299        1   0.000258       0.000258
# sadness               0.078535        2  -0.007920       0.007920
# anxiety               0.071723       22  -0.027992       0.027992
# cutting               0.069747        8  -0.002843       0.002843
# cupboard              0.068053        1   0.043028       0.043028
# low                   0.067802       14   0.000944       0.000944
# antidepressants       0.066875        3  -0.002921       0.002921
# ligature              0.064197        1   0.054751       0.054751
# mood                  0.064015        7   0.005012       0.005012
# disabled              0.063499        1   0.000056       0.000056
# unhappy               0.061363        2  -0.023971       0.023971
# bereavement           0.060349        1  -0.000512       0.000512
# depressants           0.058598        2   0.003432       0.003432
# sucidial              0.058341        1   0.074663       0.074663
# pressure              0.055573        2  -0.008094       0.008094
# transgender           0.055562        1  -0.015694       0.015694
# agrophobic            0.051325        1  -0.029699       0.029699
# pandemic              0.050525        2  -0.000760       0.000760

# %% [markdown]
# ## Substance Use

# %%
og_ml = aggregate_exps(pickle.load(open("saved/substance/og_ml_exp_raw.pickle", "rb")))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))

# %%
finetuned_ml = aggregate_exps(pickle.load(open("saved/substance/finetune_ml_exp_raw.pickle", "rb")))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))

# %%
everything = pd.concat([og_ml, finetuned_ml], axis=1, join='outer')
everything = everything.drop(columns=['value', 'abs_average'])
everything.columns = ['og_count', 'og_avg', 'ft_count', 'ft_avg']
everything.sort_values('ft_avg', ascending=False)[:25]
# Out:
#              og_count    og_avg  ft_count    ft_avg
# cannabis          7.0  0.264703       7.0  0.205985
# drinking         43.0  0.153517      45.0  0.157050
# cocaine          11.0  0.143026       9.0  0.128862
# alcohol          46.0  0.104702      48.0  0.126127
# smoking           8.0  0.129075       9.0  0.122774
# addiction        23.0  0.138053      23.0  0.120776
# drugs            34.0  0.124240      35.0  0.109900
# fentanyl          1.0  0.122019       1.0  0.103016
# drug             28.0  0.086510      29.0  0.096544
# nicotine          2.0  0.093729       2.0  0.080204
# codeine           2.0  0.107325       2.0  0.077789
# Cannabis          1.0 -0.021930       1.0  0.071740
# Drugs             NaN       NaN       1.0  0.070750
# marijuana         1.0  0.042672       1.0  0.066966
# sober            14.0  0.060084      14.0  0.066278
# substance        16.0  0.080088      16.0  0.064711
# downing           1.0  0.050621       1.0  0.064655
# substances        7.0  0.066941       7.0  0.062224
# weed             10.0  0.090503      13.0  0.057701
# smoked            7.0  0.055803       7.0  0.056347
# alcoholic         7.0  0.079145       7.0  0.056225
# paracetamol       1.0  0.264529       1.0  0.055134
# abstinent         1.0  0.060285       1.0  0.053660
# mom               1.0  0.055723       1.0  0.052359
# intoxicated       1.0  0.070665       1.0  0.051529

# %%
everything.loc['quitting']
# Out:
# og_count    5.000000
# og_avg      0.069769
# ft_count    5.000000
# ft_avg      0.030224
# Name: quitting, dtype: float64
